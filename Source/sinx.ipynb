# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin
from numpy import pi as PI

# %%
def f(x):
    return sin(x)/x

# %%
x = np.linspace(-10*PI, 10*PI, 1000)
y = f(x)
y1 = f(x+1*PI)
y2 = f(x+2*PI)
y3 = f(x+3*PI)

# Define the derivative:
d_dx = FinDiff(0, x, 1)

# Apply it:
df_dx = d_dx(y)

# %%
plt.plot(x,y)
# plt.axis('square')
plt.xlim(-10*PI,10*PI)
# plt.ylim(-1,1)
plt.grid(True)
plt.show()

# %%
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
# plt.axis('square')
plt.xlim(-10*PI,10*PI)
# plt.ylim(-1,1)
plt.grid(True)
plt.show()
